# %%
#Importamos las librerías necesarias

import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
import numpy as np
import matplotlib.mlab as mlab

# %% [markdown]
# # Pregunta 1
# ¿Cuantos nodos tiene la red?

# %%
#Para empezar a trabajar, asignamos la función de lectura del archivo 'coliInterFullVecNames.txt' a una variable FullVec

FullVecNames= pd.read_csv('coliInterFullNames.txt', delimiter = ' ')

#El archivo 'coliInterFullVecNames.txt' contiene el nombre de todos los genes que participan en la red.
#Con la función 'len' list.readlines nos permitimos contar el número de filas dentro del archivo.
#Y por lo tanto, saber el número de nodos.

#print(len(FullVecNames.readlines()))


FullN = "coliInterFullNames.txt"
count = 0
with open(FullN, 'r') as f:
    for line in f:
        count += 1.
        print("Total number of lines is:", count)
# Out:
# Total number of lines is: 1.0
# Total number of lines is: 2.0
# Total number of lines is: 3.0
# Total number of lines is: 4.0
# Total number of lines is: 5.0
# Total number of lines is: 6.0
# Total number of lines is: 7.0
# Total number of lines is: 8.0
# Total number of lines is: 9.0
# Total number of lines is: 10.0
# Total number of lines is: 11.0
# Total number of lines is: 12.0
# Total number of lines is: 13.0
# Total number of lines is: 14.0
# Total number of lines is: 15.0
# Total number of lines is: 16.0
# Total number of lines is: 17.0
# Total number of lines is: 18.0
# Total number of lines is: 19.0
# Total number of lines is: 20.0
# Total number of lines is: 21.0
# Total number of lines is: 22.0
# Total number of lines is: 23.0
# Total number of lines is: 24.0
# Total number of lines is: 25.0
# Total number of lines is: 26.0
# Total number of lines is: 27.0
# Total number of lines is: 28.0
# Total number of lines is: 29.0
# Total number of lines is: 30.0
# ...

# %% [markdown]
# # Pregunta 2
# ¿Cuántas aristas tiene la red?

# %%
#El archivo 'coliInterFullVec' contiene el número total de interacciones en la red.

FullVec = pd.read_csv('coliInterFullVec.txt', delimiter = ' ')

#Leemos el archivo y con el siguiente ciclo, contamos el total de líneas. Cada arista es una interacción y cada interacción, una línea en el archivo de texto.

FullVec = "coliInterFullVec.txt"
count = 0
with open(FullVec, 'r') as f:
    for line in f:
        count += 1.
        print("Total number of lines is:", count)
# Out:
# Total number of lines is: 1.0
# Total number of lines is: 2.0
# Total number of lines is: 3.0
# Total number of lines is: 4.0
# Total number of lines is: 5.0
# Total number of lines is: 6.0
# Total number of lines is: 7.0
# Total number of lines is: 8.0
# Total number of lines is: 9.0
# Total number of lines is: 10.0
# Total number of lines is: 11.0
# Total number of lines is: 12.0
# Total number of lines is: 13.0
# Total number of lines is: 14.0
# Total number of lines is: 15.0
# Total number of lines is: 16.0
# Total number of lines is: 17.0
# Total number of lines is: 18.0
# Total number of lines is: 19.0
# Total number of lines is: 20.0
# Total number of lines is: 21.0
# Total number of lines is: 22.0
# Total number of lines is: 23.0
# Total number of lines is: 24.0
# Total number of lines is: 25.0
# Total number of lines is: 26.0
# Total number of lines is: 27.0
# Total number of lines is: 28.0
# Total number of lines is: 29.0
# Total number of lines is: 30.0
# ...

# %% [markdown]
# # Pregunta 3
# ¿Cuántos genes se autoregulan?

# %% [markdown]
# # Pregunta 4
# ¿Cuántos genes regulan a cada gen?

# %%
df = DataFrame(FullVec, columns = ['opn', 'tfn', 'rt'])
dups_tfn = df.pivot_table(index=['tfn'], aggfunc='size')
print(dups_tfn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e8f84270e0f6> in <module>
# ----> 1 df = DataFrame(FullVec, columns = ['opn', 'tfn', 'rt'])
#       2 dups_tfn = df.pivot_table(index=['tfn'], aggfunc='size')
#       3 print(dups_tfn)
#
# NameError: name 'DataFrame' is not defined

# %%
#Con la función list.loc[] nos permitimos seleccionar todas las filas (':') dentro de la columna de 'tfn' y asignarlo a una variable x
x = FullVec.loc[:,'tfn']
num_bins = 10

#Una vez definida la variable procedemos a utilizarla en la función de histograma.

n, bins, patches = plt.hist(x, num_bins, facecolor='blue', alpha=0.5)
plt.show()

# %% [markdown]
# # Pregunta 5
# ¿Cuántos genes son autoregulados por cada TF?

# %%
#Asignamos los valores de las filas tfn y opn, cada una a una variable. 
#Utilizamos de nuevo la función list.loc
x = FullVec.loc[:,'tfn']
y = FullVec.loc[:,'opn']

#Utilizammos la función intersection. La cual nos permite comparar dos listas y arroja los caracteres similares en ambas.
list(set(x).intersection(set(y)))


#http://swcarpentry.github.io/python-novice-gapminder/08-data-frames/index.html
#https://docs.python.org/3/tutorial/datastructures.html#more-on-lists
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-bac22c55380f> in <module>
#       1 #Asignamos los valores de las filas tfn y opn, cada una a una variable.
#       2 #Utilizamos de nuevo la función list.loc
# ----> 3 x = FullVec.loc[:,'tfn']
#       4 y = FullVec.loc[:,'opn']
#       5
#
# AttributeError: 'str' object has no attribute 'loc'
